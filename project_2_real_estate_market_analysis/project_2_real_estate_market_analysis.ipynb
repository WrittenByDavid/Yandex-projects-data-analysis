# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
#
# <div class="toc">
#     <ul class="toc-item">
#         <li>
#             <span>
#                 <a href="#Описание-проекта-—-Исследование-объявлений-о-продаже-квартир" data-toc-modified-id="Описание-проекта-—-Исследование-объявлений-о-продаже-квартир-1">
#                     <span class="toc-item-num">
#                         1&nbsp;&nbsp;
#                     </span>
#                     Описание проекта — Исследование объявлений о продаже квартир
#                 </a>
#             </span>
#             <ul class="toc-item">
#                 <li>
#                     <span>
#                         <a href="#Цели-и-задачи-проекта" data-toc-modified-id="Цели-и-задачи-проекта-1.1">
#                             <span class="toc-item-num">
#                                 1.1&nbsp;&nbsp;
#                             </span>
#                             Цели и задачи проекта
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2">
#                             <span class="toc-item-num">
#                                 1.2&nbsp;&nbsp;
#                             </span>
#                             Описание данных
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#План-работы" data-toc-modified-id="План-работы-1.3">
#                             <span class="toc-item-num">
#                                 1.3&nbsp;&nbsp;
#                             </span>
#                             План работы
#                         </a>
#                     </span>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span>
#                 <a href="#Загрузка,-обзор-и-подготовка-данных" data-toc-modified-id="Загрузка,-обзор-и-подготовка-данных-2">
#                     <span class="toc-item-num">
#                         2&nbsp;&nbsp;
#                     </span>
#                     Загрузка, обзор и подготовка данных
#                 </a>
#             </span>
#             <ul class="toc-item">
#                 <li>
#                     <span>
#                         <a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1">
#                             <span class="toc-item-num">
#                                 2.1&nbsp;&nbsp;
#                             </span>
#                             Загрузка данных
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-2.2">
#                             <span class="toc-item-num">
#                                 2.2&nbsp;&nbsp;
#                             </span>
#                             Обзор данных
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2.3">
#                             <span class="toc-item-num">
#                                 2.3&nbsp;&nbsp;
#                             </span>
#                             Подготовка данных
#                         </a>
#                     </span>
#                     <ul class="toc-item">
#                         <li>
#                             <span>
#                                 <a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-2.3.1">
#                                     <span class="toc-item-num">
#                                         2.3.1&nbsp;&nbsp;
#                                     </span>
#                                     Заполнение пропусков
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.3.2">
#                                     <span class="toc-item-num">
#                                         2.3.2&nbsp;&nbsp;
#                                     </span>
#                                     Изменение типов данных
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Удаление-дубликатов" data-toc-modified-id="Удаление-дубликатов-2.3.3">
#                                     <span class="toc-item-num">
#                                         2.3.3&nbsp;&nbsp;
#                                     </span>
#                                     Удаление дубликатов
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Добавление-новых-столбцов" data-toc-modified-id="Добавление-новых-столбцов-2.3.4">
#                                     <span class="toc-item-num">
#                                         2.3.4&nbsp;&nbsp;
#                                     </span>
#                                     Добавление новых столбцов
#                                 </a>
#                             </span>
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span>
#                 <a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3">
#                     <span class="toc-item-num">
#                         3&nbsp;&nbsp;
#                     </span>
#                     Исследовательский анализ данных
#                 </a>
#             </span>
#             <ul class="toc-item">
#                 <li>
#                     <span>
#                         <a href="#Изучение-общей-площади" data-toc-modified-id="Изучение-общей-площади-3.1">
#                             <span class="toc-item-num">
#                                 3.1&nbsp;&nbsp;
#                             </span>
#                             Изучение общей площади
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Изучение-стоимости-квадратного-метра" data-toc-modified-id="Изучение-стоимости-квадратного-метра-3.2">
#                             <span class="toc-item-num">
#                                 3.2&nbsp;&nbsp;
#                             </span>
#                             Изучение стоимости квадратного метра
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Изучение-полной-стоимости" data-toc-modified-id="Изучение-полной-стоимости-3.3">
#                             <span class="toc-item-num">
#                                 3.3&nbsp;&nbsp;
#                             </span>
#                             Изучение полной стоимости
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Изучение-количества-комнат" data-toc-modified-id="Изучение-количества-комнат-3.4">
#                             <span class="toc-item-num">
#                                 3.4&nbsp;&nbsp;
#                             </span>
#                             Изучение количества комнат
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Изучение-высоты-потолков" data-toc-modified-id="Изучение-высоты-потолков-3.5">
#                             <span class="toc-item-num">
#                                 3.5&nbsp;&nbsp;
#                             </span>
#                             Изучение высоты потолков
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Изучение-длительности-продажи" data-toc-modified-id="Изучение-длительности-продажи-3.6">
#                             <span class="toc-item-num">
#                                 3.6&nbsp;&nbsp;
#                             </span>
#                             Изучение длительности продажи
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-стоимости-квадратного-метра-от-площади" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-площади-3.7">
#                             <span class="toc-item-num">
#                                 3.7&nbsp;&nbsp;
#                             </span>
#                             Зависимость стоимости квадратного метра от площади
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-стоимости-квадратного-метра-от-количества-комнат" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-количества-комнат-3.8">
#                             <span class="toc-item-num">
#                                 3.8&nbsp;&nbsp;
#                             </span>
#                             Зависимость стоимости квадратного метра от количества комнат
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-стоимости-квадратного-метра-от-удалённости-от-центра" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-удалённости-от-центра-3.9">
#                             <span class="toc-item-num">
#                                 3.9&nbsp;&nbsp;
#                             </span>
#                             Зависимость стоимости квадратного метра от удалённости от центра
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-стоимости-квадратного-метра-от-этажа" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-этажа-3.10">
#                             <span class="toc-item-num">
#                                 3.10&nbsp;&nbsp;
#                             </span>
#                             Зависимость стоимости квадратного метра от этажа
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-стоимости-квадратного-метра-от-даты-размещения-объявления" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-даты-размещения-объявления-3.11">
#                             <span class="toc-item-num">
#                                 3.11&nbsp;&nbsp;
#                             </span>
#                             Зависимость стоимости квадратного метра от даты размещения объявления
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-полной-стоимости-от-площади" data-toc-modified-id="Зависимость-полной-стоимости-от-площади-3.12">
#                             <span class="toc-item-num">
#                                 3.12&nbsp;&nbsp;
#                             </span>
#                             Зависимость полной стоимости от площади
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-полной-стоимости-от-количества-комнат" data-toc-modified-id="Зависимость-полной-стоимости-от-количества-комнат-3.13">
#                             <span class="toc-item-num">
#                                 3.13&nbsp;&nbsp;
#                             </span>
#                             Зависимость полной стоимости от количества комнат
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-полной-стоимости-от-удалённости-от-центра" data-toc-modified-id="Зависимость-полной-стоимости-от-удалённости-от-центра-3.14">
#                             <span class="toc-item-num">
#                                 3.14&nbsp;&nbsp;
#                             </span>
#                             Зависимость полной стоимости от удалённости от центра
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-полной-стоимости-от-этажа" data-toc-modified-id="Зависимость-полной-стоимости-от-этажа-3.15">
#                             <span class="toc-item-num">
#                                 3.15&nbsp;&nbsp;
#                             </span>
#                             Зависимость полной стоимости от этажа
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Зависимость-полной-стоимости-от-даты-размещения-объявления" data-toc-modified-id="Зависимость-полной-стоимости-от-даты-размещения-объявления-3.16">
#                             <span class="toc-item-num">
#                                 3.16&nbsp;&nbsp;
#                             </span>
#                             Зависимость полной стоимости от даты размещения объявления
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Расчёт-средней-стоимости-квадратного-метра" data-toc-modified-id="Расчёт-средней-стоимости-квадратного-метра-3.17">
#                             <span class="toc-item-num">
#                                 3.17&nbsp;&nbsp;
#                             </span>
#                             Расчёт средней стоимости квадратного метра
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Определение-центра-города" data-toc-modified-id="Определение-центра-города-3.18">
#                             <span class="toc-item-num">
#                                 3.18&nbsp;&nbsp;
#                             </span>
#                             Определение центра города
#                         </a>
#                     </span>
#                 </li>
#                 <li>
#                     <span>
#                         <a href="#Изучение-параметров-квартир-для-центра-города" data-toc-modified-id="Изучение-параметров-квартир-для-центра-города-3.19">
#                             <span class="toc-item-num">
#                                 3.19&nbsp;&nbsp;
#                             </span>
#                             Изучение параметров квартир для центра города
#                         </a>
#                     </span>
#                     <ul class="toc-item">
#                         <li>
#                             <span>
#                                 <a href="#Изучение-общей-площади-для-центра-города" data-toc-modified-id="Изучение-общей-площади-для-центра-города-3.19.1">
#                                     <span class="toc-item-num">
#                                         3.19.1&nbsp;&nbsp;
#                                     </span>
#                                     Изучение общей площади для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Изучение-стоимости-квадратного-метра-для-центра-города" data-toc-modified-id="Изучение-стоимости-квадратного-метра-для-центра-города-3.19.2">
#                                     <span class="toc-item-num">
#                                         3.19.2&nbsp;&nbsp;
#                                     </span>
#                                     Изучение стоимости квадратного метра для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Изучение-количества-комнат-для-центра-города" data-toc-modified-id="Изучение-количества-комнат-для-центра-города-3.19.3">
#                                     <span class="toc-item-num">
#                                         3.19.3&nbsp;&nbsp;
#                                     </span>
#                                     Изучение количества комнат для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Изучение-высоты-потолков-для-центра-города" data-toc-modified-id="Изучение-высоты-потолков-для-центра-города-3.19.4">
#                                     <span class="toc-item-num">
#                                         3.19.4&nbsp;&nbsp;
#                                     </span>
#                                     Изучение высоты потолков для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-стоимости-квадратного-метра-от-количества-комнат-для-центра-города" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-количества-комнат-для-центра-города-3.19.5">
#                                     <span class="toc-item-num">
#                                         3.19.5&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость стоимости квадратного метра от количества комнат для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-стоимости-квадратного-метра-от-этажа-для-центра-города" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-этажа-для-центра-города-3.19.6">
#                                     <span class="toc-item-num">
#                                         3.19.6&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость стоимости квадратного метра от этажа для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-стоимости-квадратного-метра-от-удалённости-от-центра-для-центра-города" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-удалённости-от-центра-для-центра-города-3.19.7">
#                                     <span class="toc-item-num">
#                                         3.19.7&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость стоимости квадратного метра от удалённости от центра для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-стоимости-квадратного-метра-от-даты-размещения-объявления-для-центра-города" data-toc-modified-id="Зависимость-стоимости-квадратного-метра-от-даты-размещения-объявления-для-центра-города-3.19.8">
#                                     <span class="toc-item-num">
#                                         3.19.8&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость стоимости квадратного метра от даты размещения объявления для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-полной-стоимости-от-количества-комнат-для-центра-города" data-toc-modified-id="Зависимость-полной-стоимости-от-количества-комнат-для-центра-города-3.19.9">
#                                     <span class="toc-item-num">
#                                         3.19.9&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость полной стоимости от количества комнат для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-полной-стоимости-от-этажа-для-центра-города" data-toc-modified-id="Зависимость-полной-стоимости-от-этажа-для-центра-города-3.19.10">
#                                     <span class="toc-item-num">
#                                         3.19.10&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость полной стоимости от этажа для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-полной-стоимости-от-удалённости-от-центра-для-центра-города" data-toc-modified-id="Зависимость-полной-стоимости-от-удалённости-от-центра-для-центра-города-3.19.11">
#                                     <span class="toc-item-num">
#                                         3.19.11&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость полной стоимости от удалённости от центра для центра города
#                                 </a>
#                             </span>
#                         </li>
#                         <li>
#                             <span>
#                                 <a href="#Зависимость-полной-стоимости-от-даты-размещения-объявления-для-центра-города" data-toc-modified-id="Зависимость-полной-стоимости-от-даты-размещения-объявления-для-центра-города-3.19.12">
#                                     <span class="toc-item-num">
#                                         3.19.12&nbsp;&nbsp;
#                                     </span>
#                                     Зависимость полной стоимости от даты размещения объявления для центра города
#                                 </a>
#                             </span>
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span>
#                 <a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-4">
#                     <span class="toc-item-num">
#                         4&nbsp;&nbsp;
#                     </span>
#                     Общий вывод
#                 </a>
#             </span>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# # Описание проекта — Исследование объявлений о продаже квартир
# ## Цели и задачи проекта
#
# + Необходимо установить и проанализировать основные параметры, характеризующие объекты недвижимости.
# + Необходимо изучить зависимость между этими параметрами и стоимостью объектов недвижимости.
#
# ## Описание данных
#
# Сервис Яндекc.Недвижимость предоставил архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра города, аэропорта, ближайшего парка и водоёма. Архив объявлений представляет собой датасет со следующими столбцами:
#
# + `total_images` — число фотографий квартиры в объявлении
# + `last_price` — цена на момент снятия с публикации (рублей)
# + `total_area` — площадь квартиры в квадратных метрах (м²)
# + `first_day_exposition` — дата публикации
# + `rooms` — число комнат
# + `ceiling_height` — высота потолков (м)
# + `floors_total` — всего этажей в доме
# + `living_area` — жилая площадь в квадратных метрах (м²)
# + `floor` — этаж
# + `is_apartment` — апартаменты (булев тип)
# + `studio` — квартира-студия (булев тип)
# + `open_plan` — свободная планировка (булев тип)
# + `kitchen_area` — площадь кухни в квадратных метрах (м²)
# + `balcony` — число балконов
# + `locality_name` — название населённого пункта
# + `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# + `city_centers_nearest` — расстояние до центра города (м)
# + `parks_around_3000` — число парков в радиусе 3 км
# + `parks_nearest` — расстояние до ближайшего парка (м)
# + `ponds_around_3000` — число водоёмов в радиусе 3 км
# + `ponds_nearest` — расстояние до ближайшего водоёма (м)
# + `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
#
#
# ## План работы
#
# + Загрузить и изучить данные
# + Провести предобработку данных
# + Провести исследовательский анализ данных
# + Сделать общий вывод

# %% [markdown]
# # Загрузка, обзор и подготовка данных
# ## Загрузка данных
# Импортируем необходимые библиотеки, прочитаем файл `real_estate_data.csv` и посмотрим первые строки таблицы `df`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('real_estate_data.csv')
df.head()
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# Данные склеились в одну строку вместо того, чтобы разбиться по колонкам. Очевидно, что это произошло из-за использования `\t` в качестве разделителя, вместо запятой. Ещё раз прочитаем файл `real_estate_data.csv` указав `\t` в качестве разделителя и снова посмотрим первые строки таблицы `df`.

# %%
df = pd.read_csv('real_estate_data.csv', sep='\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Проблема решилась, но теперь при выводе данных отображаются только 20 из 22 столбцов. Конечно можно прочитать их отдельно командой `df[['studio', 'open_plan']].head()`, но так как в дальнейшем планируется добавлять новые столбцы и неоднократно придётся выводить данные, то лучше снять ограничения на количество выводимых столбцов используя метод `set_option()`.

# %%
# Сброс ограничений на число выводимых столбцов
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Обзор данных
# Посмотрим первые и последние 10 строк таблицы `df`.

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0        51.00      8          NaN   False
# ...

# %%
df.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23689            2.86          15.0         16.3      4          NaN   False
# ...

# %% [markdown]
# Посмотрим общую информацию о данных в таблице `df`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Посмотрим названия колонок таблицы `df`.

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# В названиях колонок `cityCenters_nearest`, `parks_around3000` и `ponds_around3000` наблюдается смешение стилей `CamelCase` и `snake_case`. Приведём все названия к единому стилю `snake_case`.

# %%
df = df.rename(
    columns={
        'cityCenters_nearest': 'city_centers_nearest',
        'parks_around3000': 'parks_around_3000',
        'ponds_around3000': 'ponds_around_3000'
    }
)

# %% [markdown]
# Ещё раз посмотрим названия колонок таблицы `df`.

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# ИТОГО:
# 1. Мы работаем с таблицей размером 23699 строк на 22 столбца.
# 2. Количество значений в столбцах различается. Значит в данных есть пропущенные значения.
# 3. Столбец `last_price` можно привести из типа `float` к типу `int`, так как после запятой идут уже копейки.
# 4. Столбец `first_day_exposition` нужно привести из типа `object` к типу `datetime`.
# 5. В столбце `is_apartment` заполнено всего 12% ячеек, также этот столбец нужно привести из типа `object` к типу `bool`.
# 6. Столбцы `airports_nearest`, `city_centers_nearest`, `parks_nearest` и `ponds_nearest` можно привести из типа `float` к типу `int`, так как после запятой идут уже сантиметры.
# 7. Столбцы `floors_total`, `balcony`, `parks_around_3000`, `ponds_around_3000` и `days_exposition` нужно привести из типа `float` к типу `int`, так как значения этих столбцов измеряются только целым числом.

# %% [markdown]
# ## Подготовка данных
# ### Заполнение пропусков
# Посчитаем количество пропущенных значений в таблице `df`.

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Пропуски есть в 14 столбцах из 22 и их количество составляет 19,5% от общего объёма данных. Разберём отдельно каждый из 14 столбцов.
#
# + **Рассмотрим столбец** `ceiling_height`
#
# В данном столбце не заполнено 38,8% ячеек. Скорее всего пользователи, просто не заполняли данный раздел при публикации объявления. Но пропуски в высоте потолков можно считать критичными, так как данный параметр должен влиять на стоимость квартиры. Мы можем определить зависимость высоты потолков от стоимости 1 м² и заполнить пропуски на основании этих данных. Разобьём все квартиры на 4 группы по стоимости за 1 м²: `дешевле 100.000`, `от 100.000 до 150.000`, `от 150.000 до 200.000` и `свыше 200.000`. Потом найдём медианное значение высоты потолка для каждой группы и заполним пропуски столбца `ceiling_height` на основании полученных значений. Но предварительно взглянем на среднеарифметическое, медиану, минимум и максимум столбца `ceiling_height`.

# %%
df['ceiling_height'].mean(), df['ceiling_height'].median(), df['ceiling_height'].min(), df['ceiling_height'].max()
# Out:
# (2.7714988968559835, 2.65, 1.0, 100.0)

# %% [markdown]
# Cреднеарифметическое и медиана очень близки другу к дургу по значениям, но так как наблюдаются аномальные выбросы в виде высоты потолков в 1 и 100 метров, то для заполнения пропусков всё-таки лучше подойдёт медиана. Теперь найдём медианное значение высоты потолка для каждой из четырёх групп.

# %%
row_1 = (df['last_price']/df['total_area'])<=100000
row_2 = ((df['last_price']/df['total_area'])>100000) & ((df['last_price']/df['total_area'])<=150000)
row_3 = ((df['last_price']/df['total_area'])>150000) & ((df['last_price']/df['total_area'])<=200000)
row_4 = (df['last_price']/df['total_area'])>200000
[
df.loc[row_1, 'ceiling_height'].median(),
df.loc[row_2, 'ceiling_height'].median(),
df.loc[row_3, 'ceiling_height'].median(),
df.loc[row_4, 'ceiling_height'].median()
]
# Out:
# [2.6, 2.7, 3.0, 3.06]

# %% [markdown]
# Наблюдается отчётливая зависимость. Высота потолков увеличивается с ростом стоимости за 1 м². Заполним пропуски в столбце `ceiling_height` согласно этой градации.

# %%
df.loc[row_1, 'ceiling_height'] = df.loc[row_1, 'ceiling_height'].fillna(2.6)
df.loc[row_2, 'ceiling_height'] = df.loc[row_2, 'ceiling_height'].fillna(2.7)
df.loc[row_3, 'ceiling_height'] = df.loc[row_3, 'ceiling_height'].fillna(3.0)
df.loc[row_4, 'ceiling_height'] = df.loc[row_4, 'ceiling_height'].fillna(3.06)

# %% [markdown]
# + **Рассмотрим столбец** `floors_total`
#
# Количество пропусков в столбце `floors_total` очень мало и сами пропуски абсолютно не критичны. Взглянем на среднеарифметическое, медиану, минимум и максимум этого столбца.

# %%
df['floors_total'].mean(), df['floors_total'].median(), df['floors_total'].min(), df['floors_total'].max()
# Out:
# (10.67382374115953, 9.0, 1.0, 60.0)

# %% [markdown]
# Cреднеарифметическое и медиана очень близки другу к дургу по значениям, но наблюдается значительный выброс в виде 60 этажа, поэтому для заполнения пропусков лучше использовать медиану. Но так как этаж квартиры может оказаться больше медианы, то используем медиану для тех пропусков, где этаж квартиры меньше или равен 9 этажу. Остальные пропуски заполним значением `df['floor']+1`, то есть будем брать на этаж выше текущего, так как даже миниальное увеличение квартир находящихся на последнем этаже может исказить данные, в связи с тем, что квартир на первом и последнем этажах должно быть значительно меньше, чем всех остальных.

# %%
df.loc[df['floor']<=9, 'floors_total'] = df.loc[df['floor']<=9, 'floors_total'].fillna(9.0)
df.loc[df['floor']>9, 'floors_total'] = df.loc[df['floor']>9, 'floors_total'].fillna(df['floor']+1)

# %% [markdown]
# + **Рассмотрим столбцы** `living_area` и `kitchen_area`
#
# В столбце `living_area` всего 8% пропусков, а в столбце `kitchen_area` всего 9,6% пропусков и они заполнены значениями `NaN`. Причиной пропусков может быть то, что это квартиры без отделки и без межкомнатных перегородок. Жилая площадь и площадь кухни не интересны нам в чистом виде. В дальнейшем нам будет интересно их соотношение с общей площадью. Поскольку в столбце с общей площадью нет пропусков и со значением `NaN` можно производить арифметические операции, то оставим пропуски столбцов `living_area` и `kitchen_area` без изменений, а уже после добавления в таблицу двух новых столбцов с соотношением их площади к общей, заполним пропуски этих новых столбцов их медианным значением.
#
# + **Рассмотрим столбец** `is_apartment`
#
# В столбце `is_apartment` 88,3% пропусков. Самая очевидная причина — это то, что недвижимость не является апартаментами. Поэтому просто заполним все пропуски значением `False`. Также так как в столбце могут храниться данные только одного типа, то все значения автоматически приведутся из типа `object` к типу `bool`.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# + **Рассмотрим столбец** `balcony`
#
# В столбце `balcony` 48,6% пропусков. Самая очевидная причина — это отсутствие балкона, поэтому просто заполним все пропуски нулями.

# %%
df['balcony'] = df['balcony'].fillna(0)

# %% [markdown]
# + **Рассмотрим столбец** `locality_name`
#
# В столбце `locality_name` всего лишь 0,2% пропусков. Возможная причина — названия некоторых населённых пунктов просто отсутствуют в вариантах выбора для пользователя. Заполним все пропуски значением `unknown`. Но сперва, так как столбец `locality_name` хранит категориальные значения, убедимся в отсутствии скрытых пропусков, например значения `'None'` записанного в виде строки.

# %%
# Выведем таблицу df отфильтрованную по возможным скрытым пропускам
len(df.loc[df['locality_name'].isin(['None', 'NaN', 'Null', 'unknown', '0', '-'])])
# Out:
# 0

# %% [markdown]
# Скрытых пропусков нет. Теперь можем заполнить все пропуски значением `unknown`.

# %%
df['locality_name'] = df['locality_name'].fillna('unknown')

# %% [markdown]
# + **Рассмотрим столбцы** `airports_nearest`, `city_centers_nearest`, `parks_nearest` и `ponds_nearest`
#
# Количество пропусков в данных столбцах следующее: `airports_nearest - 23,4%`, `city_centers_nearest - 23,3%`, `parks_nearest - 65,9%`, `ponds_nearest - 61,6%`. Можно предположить, что пользователи просто не заполняли данные разделы, но в описании проекта говорится, что такие значения как расстояние до центра, аэропорта, ближайшего парка и водоёма получены автоматически на основе картографических данных. То есть система скорее всего имеет адрес квартиры и на его основе автоматически заполняет эти столбцы. Тогда можно предположить, что пользователь неккоректно заполнил адрес, но тогда например в столбцах `parks_nearest` и `parks_around_3000` должно быть одинаковое количество пропусков, а по факту у них трёхкратная разница. С другой стороны, неизвестно как заполняется столбец `parks_around_3000` автоматически или пользователем. Оставим пропуски столбцов `airports_nearest`, `city_centers_nearest`, `parks_nearest` и `ponds_nearest` без изменений. Также тогда мы не сможем привести их из типа `float` к типу `int`, но это никак не повлияет на наше исследование.
#
# + **Рассмотрим столбцы** `parks_around_3000` и `ponds_around_3000`
#
# В столбцах `parks_around_3000` и `ponds_around_3000` по 23,3% пропусков. Отсутствие значений может говорить об отсутствии парка или водоёма в радиусе 3 км. Также во время обзора данных было видно, что некоторые ячейки в этих столбцах заполнены значением ноль, что тоже говорит об отсутствии парка или водоёма в радиусе 3 км. Приведём всё к единому стилю и заполним все пропуски нулями.

# %%
df['parks_around_3000'] = df['parks_around_3000'].fillna(0)
df['ponds_around_3000'] = df['ponds_around_3000'].fillna(0)

# %% [markdown]
# + **Рассмотрим столбец** `days_exposition`
#
# В столбце `days_exposition` 13,4% пропусков. Взглянем на среднеарифметическое, медиану, минимум и максимум этого столбца.

# %%
df['days_exposition'].mean(), df['days_exposition'].median(), df['days_exposition'].min(), df['days_exposition'].max()
# Out:
# (180.88863436982163, 95.0, 1.0, 1580.0)

# %% [markdown]
# Наблюдаются значительные выбросы и как следствие почти двухкратная разница между медианой и среднеарифметическим. Оставим пропуски пока как есть.
#
# + **Ещё раз проверим количество пропусков таблицы** `df` **после всех изменений.**

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1903
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name               0
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000           0
# parks_nearest           15620
# ponds_around_3000           0
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# ### Изменение типов данных
# Ещё раз проговорим в каких столбцах и почему будем изменять типы данных:
# + Столбец `first_day_exposition` из типа `object` к типу `datetime`, так как это дата публикации объявления.
# + Столбец `last_price` из типа `float` к типу `int`, так как после запятой идут уже копейки.
# + Столбцы `floors_total`, `balcony`, `parks_around_3000` и `ponds_around_3000` из типа `float` к типу `int`, так как значения этих столбцов измеряются только целым числом.
#
# Теперь проведём изменение типов данных методами `astype()` и `to_datetime()`.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%d')
df = df.astype({
    'last_price': 'int',
    'floors_total': 'int',
    'balcony': 'int',
    'parks_around_3000': 'int',
    'ponds_around_3000': 'int',
})

# %% [markdown]
# Проверим типы данных после сделанных изменений.

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                       int32
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int32
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int32
# locality_name                   object
# airports_nearest               float64
# city_centers_nearest           float64
# parks_around_3000                int32
# parks_nearest                  float64
# ponds_around_3000                int32
# ponds_nearest                  float64
# days_exposition                float64
# dtype: object

# %% [markdown]
# ### Удаление дубликатов
# Проверим таблицу `df` на наличие явных дубликатов.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не оказалось, значит каждая строка таблицы `df` уникальна.

# %% [markdown]
# ### Добавление новых столбцов
#
# + Добавим в исходную таблицу `df` столбец `price_square_meter`, в котором будет храниться цена за 1 м². Для удобства чтения будем хранить стоимость в тысячах рублей и округлим её до 1 знака после запятой. Остальные знаки после запятой имеют сверхмалое влияние на общую стоимость.

# %%
df['price_square_meter'] = ((df['last_price']/df['total_area'])/1000).round(1)

# %% [markdown]
# + Добавим в исходную таблицу `df` столбцы `day`, `month` и `year`, в которых будут храниться день недели, месяц и год публикации объявления соответственно.

# %%
df['day'] = df['first_day_exposition'].dt.weekday
df['month'] = df['first_day_exposition'].dt.month
df['year'] = df['first_day_exposition'].dt.year

# %% [markdown]
# + Добавим в исходную таблицу `df` столбец `flats_floor`, в котором будет храниться этаж квартиры, обозначенный одним из трёх значений: `первый`, `последний` или `другой`.

# %%
def add_flats_floor(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
df['flats_floor'] = df.apply(add_flats_floor, axis=1)

# %% [markdown]
# + Добавим в исходную таблицу `df` столбцы `ratio_living_to_total_area` и `ratio_kitchen_to_total_area` в которых будут храниться соотношения `жилая площадь/общая площадь` и `площадь кухни/общая площадь`. Также в разделе по заполнению пропусков мы хотели заполнить пропуски этих новых столбцов их медианой. Сделаем это.

# %%
df['ratio_living_to_total_area'] = df['living_area']/df['total_area']
df['ratio_living_to_total_area'] = df['ratio_living_to_total_area'].fillna(df['ratio_living_to_total_area'].median())
df['ratio_kitchen_to_total_area'] = df['kitchen_area']/df['total_area']
df['ratio_kitchen_to_total_area'] = df['ratio_kitchen_to_total_area'].fillna(df['ratio_kitchen_to_total_area'].median())

# %% [markdown]
# + Выведем первые и последние 10 строк таблицы `df` после всех изменений.

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# ...

# %%
df.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13     3550000       35.30           2018-02-28      1
# 23690             3     5500000       52.00           2018-07-19      2
# 23691            11     9470000       72.90           2016-10-13      2
# 23692             2     1350000       30.00           2017-07-07      1
# 23693             9     4600000       62.40           2016-08-05      3
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 23689            2.86            15         16.3      4         False   False
# ...

# %% [markdown]
# # Исследовательский анализ данных
# ## Изучение общей площади
#
# Изучим общую площадь, жилую площадь и площадь кухни объектов недвижимости. Построим гистограммы и используем метод `describe()` для столбцов `total_area`, `ratio_living_to_total_area` и `ratio_kitchen_to_total_area`.

# %%
# Общая площадь
df['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
# Отношение жилой площади к общей
df['ratio_living_to_total_area'].describe()
# Out:
# count    23699.000000
# mean         0.565014
# std          0.101053
# min          0.021583
# 25%          0.500000
# 50%          0.567860
# 75%          0.631579
# max          1.000000
# Name: ratio_living_to_total_area, dtype: float64

# %%
# Отношение площади кухни к общей
df['ratio_kitchen_to_total_area'].describe()
# Out:
# count    23699.000000
# mean         0.185919
# std          0.069512
# min          0.025381
# 25%          0.136859
# 50%          0.172414
# 75%          0.223717
# max          0.787879
# Name: ratio_kitchen_to_total_area, dtype: float64

# %%
plt.figure(figsize=[10,5])
df['total_area'].hist(bins=60, range = (0, 200))
plt.xlabel("Общая площадь квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по общей площади")
plt.show()

# %%
plt.figure(figsize=[10,5])
df['ratio_living_to_total_area'].hist(bins=30)
plt.xlabel("Доля жилой площади относительно общей площади квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по соотношению жилой площади к общей")
plt.show()

# %%
plt.figure(figsize=[10,5])
df['ratio_kitchen_to_total_area'].hist(bins=30)
plt.xlabel("Доля площади кухни относительно общей площади квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по соотношению площади кухни к общей")
plt.show()

# %% [markdown]
# Отношение жилой площади к общей имеет нормальное распределение. А гистограммы общей площади и отношения площади кухни к общей схожи друг с другом и имеют форму распределения Пуассона. Минимальное значение площади в 12 м² кажется выбросом, но теоретически это может быть супер малая квартира-студия. А вот максимальная площадь в 900 м² уже точно похожа на выброс. Построим укрупнённую гистограмму для столбца `total_area` в диапазоне от 200 до 1000.

# %%
plt.figure(figsize=[10,5])
df['total_area'].hist(bins=50, range=(200, 1000))
plt.xlabel("Общая площадь квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по общей площади")
plt.show()

# %% [markdown]
# Предположим, что квартиры до 400 м² это какая-нибудь супер элитная недвижимость с 16 комнатами по 25 м² например на Крестовском острове. Посмотрим сколько квартир площадью более 400 м².

# %%
len(df.loc[df['total_area']>=400])
# Out:
# 26

# %% [markdown]
# Таких квартир оказалось всего 0,11%. Удалим эти строки как редкие и выбивающиеся значения.

# %%
df = df.query('total_area<400')

# %% [markdown]
# ## Изучение стоимости квадратного метра
# Изучим стоимость 1 м² объектов недвижимости. Построим гистограмму и используем метод `describe()` для столбца `price_square_meter`.

# %%
df['price_square_meter'].describe()
# Out:
# count    23673.000000
# mean        99.198019
# std         48.236204
# min          0.100000
# 25%         76.600000
# 50%         95.000000
# 75%        114.200000
# max       1736.800000
# Name: price_square_meter, dtype: float64

# %%
plt.figure(figsize=[10,5])
df['price_square_meter'].hist(bins=50, range=(0, 300))
plt.xlabel("Стоимость квадратного метра (тысяч рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по стоимости квадратного метра")
plt.show()

# %% [markdown]
# Гистограмма стоимости за 1 м² имеет нормальное распределение. Построим дополнительно две гистограммы для диапазона от 0 до 50 и для диапазона от 300 до 1800.

# %%
plt.figure(figsize=[10,5])
df['price_square_meter'].hist(bins=50, range=(0, 50))
plt.xlabel("Стоимость квадратного метра (тысяч рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по стоимости квадратного метра")
plt.show()

# %%
plt.figure(figsize=[10,5])
df['price_square_meter'].hist(bins=50, range=(300, 1800))
plt.xlabel("Стоимость квадратного метра (тысяч рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по стоимости квадратного метра")
plt.show()

# %% [markdown]
# Объекты недвижимости со стоимостью за 1 м² в диапазоне от 0 до 10 и от 400 до 1800 кажутся редкими и выбивающимися значениями. Удалим их.

# %%
df = df.query('price_square_meter>10 and price_square_meter<400')

# %% [markdown]
# ## Изучение полной стоимости
# Изучим полную стоимость объектов недвижимости. Построим гистограмму и используем метод `describe()` для столбца `last_price`.

# %%
df['last_price'].describe()
# Out:
# count    2.359700e+04
# mean     6.117951e+06
# std      5.779845e+06
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.600000e+06
# 75%      6.700000e+06
# max      1.310000e+08
# Name: last_price, dtype: float64

# %%
plt.figure(figsize=[10,5])
df['last_price'].hist(bins=50)
plt.xlabel("Полная стоимость квартиры (* 100 млн. рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по полной стоимости")
plt.show()

# %% [markdown]
# Построим дополнительные гистограммы для диапазона от 0 до 20 и от 20 до 135 миллионов рублей.

# %%
plt.figure(figsize=[10,5])
df['last_price'].hist(bins=50, range=(0, 20000000))
plt.xlabel("Полная стоимость квартиры (* 10 млн. рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по полной стоимости")
plt.show()

# %% [markdown]
# Гистограмма тяготеет к форме нормального распределения.

# %%
plt.figure(figsize=[10,5])
df['last_price'].hist(bins=50, range=(20000000, 135000000))
plt.xlabel("Полная стоимость квартиры (* 100 млн. рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по полной стоимости")
plt.show()

# %% [markdown]
# Большинство квартир находятся в ценовом диапазоне от 2 до 7,5 миллионов рублей. Стоимости свыше 40 миллионов рублей кажутся редкими и выбивающимися. Удалим их.

# %%
df = df.query('last_price<40000000')

# %% [markdown]
# ## Изучение количества комнат
# Изучим количество комнат объектов недвижимости. Построим гистограмму и используем метод `describe()` для столбца `rooms`.

# %%
df['rooms'].describe()
# Out:
# count    23485.000000
# mean         2.050884
# std          1.047261
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
plt.figure(figsize=[10,5])
df['rooms'].hist(bins=5, range=(0, 5))
plt.xlabel("Количество комнат")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по количеству комнат")
plt.show()

# %% [markdown]
# Максимальное значение в 19 комнат ещё можно соотнести с квартирами под 400 м², которые мы оставили в предыдущем пункте. Но квартиры с нулевым значением комнат точно являются выбросами. Удалим их.

# %%
df = df.query('rooms>0')

# %% [markdown]
# ## Изучение высоты потолков
# Изучим высоту потолков объектов недвижимости. Построим гистограмму и используем метод `describe()` для столбца `ceiling_height`.

# %%
df['ceiling_height'].describe()
# Out:
# count    23289.000000
# mean         2.716469
# std          0.748504
# min          1.000000
# 25%          2.600000
# 50%          2.600000
# 75%          2.700000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
plt.figure(figsize=[10,5])
df['ceiling_height'].hist(range=(2, 3.5))
plt.xlabel("Высота потолка")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по высоте потолков")
plt.show()

# %% [markdown]
# В Санкт-Петербурге бывают квартиры с потолками до 5 метров. Отсечём все значения потолков менее 2  и более 5 метров как редкие и выбивающимися.

# %%
df = df.query('ceiling_height>2 and ceiling_height<=5')

# %% [markdown]
# Посмотрим на сколько сократился исходный массив после всех чисток.

# %%
23699-len(df)
# Out:
# 453

# %% [markdown]
# Ушло 453 строки. Это составляет 1,9% от общего объёма данных, что вполне допустимо.

# %% [markdown]
# ## Изучение длительности продажи
# Изучим время, за которое были проданы объекты недвижимости. Построим гистограмму и используем метод `describe()` для столбца `days_exposition`.

# %%
df['days_exposition'].describe()
# Out:
# count    20141.000000
# mean       180.542823
# std        219.318007
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.figure(figsize=[10,5])
df['days_exposition'].hist(bins=45)
plt.xlabel("Длительность продажи квартиры (дней)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по длительности продажи")
plt.show()

# %% [markdown]
# Построим отдельную укрупнённую гистограмму для диапазона от 0 до 365 дней.

# %%
plt.figure(figsize=[10,5])
df['days_exposition'].hist(bins=60, range=(0, 365))
plt.xlabel("Длительность продажи квартиры (дней)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по длительности продажи")
plt.show()

# %% [markdown]
# Так как имеются выбросы со значениями длительности продаж от 1000 и более дней, то в качестве линии, разграничивающей быстрые и долгие продажи, выберем медиану, а не среднеарифметическое. Как на общей, так и на укрупнённой гистограмме видно, что большинство квартир продаётся в первые 100 дней, что коррелирует с медианным значением. Таким образом можно принять, что среднее время продажи составляет 95 дней. Если ушло меньше, то продажу можно считать быстрой, а если больше, то долгой.

# %% [markdown]
# ## Зависимость стоимости квадратного метра от площади
# Изучим зависимость цены 1 м² от площади недвижимости. Построим три диаграммы рассеяния для столбцов `price_square_meter` и `total_area`, `price_square_meter` и  `ratio_living_to_total_area`, `price_square_meter` и  `ratio_kitchen_to_total_area`. Найдём коэффициенты корреляции Пирсона.

# %%
df.plot(x='price_square_meter', y='total_area', kind='scatter', alpha=0.1, figsize=[10,5])
plt.xlabel("Стоимость 1 м² (тысяч рублей)")
plt.ylabel("Общая площадь квартиры")
plt.title("Зависимость стоимости квадратно метра от площади квартиры")

df.plot(x='price_square_meter', y='ratio_living_to_total_area', kind='scatter', alpha=0.1, figsize=[10,6])
plt.xlabel("Стоимость 1 м² (тысяч рублей)")
plt.ylabel("Доля жилой площади относительно общей площади квартиры")
plt.title("Зависимость стоимости квадратно метра от соотношения жилой площади к общей")

df.plot(x='price_square_meter', y='ratio_kitchen_to_total_area', kind='scatter', alpha=0.1, figsize=[10,6])
plt.xlabel("Стоимость 1 м² (тысяч рублей)")
plt.ylabel("Доля площади кухни относительно общей площади квартиры")
plt.title("Зависимость стоимости квадратно метра от соотношения площади кухни к общей")

plt.show()

# %%
[
    df['price_square_meter'].corr(df['total_area']),
    df['price_square_meter'].corr(df['ratio_living_to_total_area']),
    df['price_square_meter'].corr(df['ratio_kitchen_to_total_area'])
]
# Out:
# [0.17228178030754202, -0.19664000969996326, 0.2143273104689112]

# %% [markdown]
# На основе полученных данных можно сказать, что показатели площади влияют на стоимость 1 м² лишь незначительно.

# %% [markdown]
# ## Зависимость стоимости квадратного метра от количества комнат
# Изучим зависимость цены 1 м² от количества комнат недвижимости. Построим диаграмму `bar plot` для столбцов `price_square_meter` и `rooms`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df.groupby('rooms')['price_square_meter'].mean().plot.bar()
plt.xlabel("Количество комнат квартиры")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от количества комнат квартиры")
plt.show()

# %%
df['price_square_meter'].corr(df['rooms'])
# Out:
# -0.03739597428653035

# %% [markdown]
# На основе полученных данных можно сказать, что количество комнат не влияет на стоимость 1 м².

# %% [markdown]
# ## Зависимость стоимости квадратного метра от удалённости от центра
# Изучим зависимость цены 1 м² от удалённости от центра объекта недвижимости. Построим диаграмму рассеяния для столбцов `price_square_meter` и `city_centers_nearest`. Найдём коэффициент корреляции Пирсона.

# %%
df.plot(x='price_square_meter', y='city_centers_nearest', kind='scatter', alpha=0.1, figsize=[10,5])
plt.xlabel("Стоимость 1 м² (тысяч рублей)")
plt.ylabel("Удалённость квартиры от центра города в метрах")
plt.title("Зависимость стоимости 1 м² от удалённости от центра города")
plt.show()

# %%
df['price_square_meter'].corr(df['city_centers_nearest'])
# Out:
# -0.38692977242080673

# %% [markdown]
# На основе полученных данных можно сказать, что удалённость от центра влияет на стоимость 1 м². Также все премиальные квартиры со стоимостью от 200 тысяч за 1 м² находятся в радиусе 10 км от центра города.

# %% [markdown]
# ## Зависимость стоимости квадратного метра от этажа
# Изучим зависимость цены 1 м² от этажа объекта недвижимости. Построим диаграмму `bar plot` для столбцов `price_square_meter` и `flats_floor`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[8,5])
df.groupby('flats_floor')['price_square_meter'].mean().plot.bar()
plt.xlabel("Этаж квартиры")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от этажа")
plt.show()

# %%
df['price_square_meter'].corr(df['city_centers_nearest'])
# Out:
# -0.38692977242080673

# %% [markdown]
# На основе полученных данных можно сказать, что этаж влияет на стоимость 1 м². Первый этаж наименее привлекателен, затем идёт последний и лучший показатель стоимости у всех остальных этажей.

# %% [markdown]
# ## Зависимость стоимости квадратного метра от даты размещения объявления
# Изучим зависимость цены 1 м² от дня, месяца и года размещения объявления. Построим три диаграммы `bar plot` для столбцов `price_square_meter` и `day`, `price_square_meter` и `month`, `price_square_meter` и `year`. Найдём коэффициенты корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df.groupby('day')['price_square_meter'].mean().plot.bar()
plt.xlabel("День недели публикации объявления")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от дня недели публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df.groupby('month')['price_square_meter'].mean().plot.bar()
plt.xlabel("Месяц публикации объявления")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от месяца публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df.groupby('year')['price_square_meter'].mean().plot.bar()
plt.xlabel("Год публикации объявления")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от года публикации объявления")
plt.show()

# %%
[
    df['price_square_meter'].corr(df['day']),
    df['price_square_meter'].corr(df['month']),
    df['price_square_meter'].corr(df['year'])
]
# Out:
# [-0.012075037998679167, -0.003485019593653041, 0.038529156142089675]

# %% [markdown]
# На основе полученных данных можно сказать, что дата публикации объявления не влияет на стоимость 1 м². Из общей картины выбивается только 2014 год, но это можно списать на малый объём данных, так как сервис Яндекс.Недвижимость запустился только в 2010 году.

# %% [markdown]
# ## Зависимость полной стоимости от площади
# Изучим зависимость полной стоимости объектов недвижимости от площади. Построим три диаграммы рассеяния для столбцов `last_price` и `total_area`, `last_price` и  `ratio_living_to_total_area`, `last_price` и  `ratio_kitchen_to_total_area`. Найдём коэффициенты корреляции Пирсона.

# %%
df.plot(x='last_price', y='total_area', kind='scatter', alpha=0.1, figsize=[10,5])
plt.xlabel("Полная стоимость квартиры (* 10 млн. рублей)")
plt.ylabel("Общая площадь квартиры")
plt.title("Зависимость полной стоимости квартиры от её площади")

df.plot(x='last_price', y='ratio_living_to_total_area', kind='scatter', alpha=0.1, figsize=[10,6])
plt.xlabel("Полная стоимость квартиры (* 10 млн. рублей)")
plt.ylabel("Доля жилой площади относительно общей площади квартиры")
plt.title("Зависимость полной стоимости квартиры от соотношения жилой площади к общей")

df.plot(x='last_price', y='ratio_kitchen_to_total_area', kind='scatter', alpha=0.1, figsize=[10,6])
plt.xlabel("Полная стоимость квартиры (* 10 млн. рублей)")
plt.ylabel("Доля площади кухни относительно общей площади квартиры")
plt.title("Зависимость полной стоимости квартиры от соотношения площади кухни к общей")

plt.show()

# %%
[
    df['last_price'].corr(df['total_area']),
    df['last_price'].corr(df['ratio_living_to_total_area']),
    df['last_price'].corr(df['ratio_kitchen_to_total_area'])
]
# Out:
# [0.7953075411202746, 0.019193571855604778, -0.11462861896837345]

# %% [markdown]
# На основе полученных данных можно сказать, что есть прямая взаимосвязь между общей площадью и полной стоимостью квартиры (что  и так очевидно). Отношение жилой площади или площади кухни к общей не влияет на стоимость.

# %% [markdown]
# ## Зависимость полной стоимости от количества комнат
# Изучим зависимость полной стоимости объектов недвижимости от количества комнат. Построим `bar plot` для столбцов `last_price` и `rooms`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df.groupby('rooms')['last_price'].mean().plot.bar()
plt.xlabel("Количество комнат квартиры")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от количества комнат")
plt.show()

# %%
df['last_price'].corr(df['rooms'])
# Out:
# 0.5235835662080125

# %% [markdown]
# С ростом стоимости растёт количество комнат.

# %% [markdown]
# ## Зависимость полной стоимости от удалённости от центра
# Изучим зависимость полной стоимости объектов недвижимости от удалённости от центра. Построим диаграмму рассеяния для столбцов `last_price` и `city_centers_nearest`. Найдём коэффициент корреляции Пирсона.

# %%
df.plot(x='last_price', y='city_centers_nearest', kind='scatter', alpha=0.1, figsize=[10,5])
plt.xlabel("Полная стоимость квартиры (* 10 млн. рублей)")
plt.ylabel("Удалённость квартиры от центра города в метрах")
plt.title("Зависимость полной стоимости квартиры от удалённости от центра")
plt.show()

# %%
df['last_price'].corr(df['city_centers_nearest'])
# Out:
# -0.33923236027216935

# %% [markdown]
# На основе полученных данных можно сказать, что удалённость от центра влияет на стоимость. Подавляющее большинство дорогой недвижимости находится в радиусе 10 км от центра города.

# %% [markdown]
# ## Зависимость полной стоимости от этажа
# Изучим зависимость полной стоимости объектов недвижимости от этажа. Построим `bar plot` для столбцов `last_price` и `flats_floor`.

# %%
plt.figure(figsize=[8,5])
df.groupby('flats_floor')['last_price'].mean().plot.bar()
plt.xlabel("Этаж квартиры")
plt.ylabel("Средняя стоимость квартиры (млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от её этажа")
plt.show()

# %% [markdown]
# На основе полученных данных можно сказать, что этаж влияет на стоимость. Самые дешёвые квартиры находятся на первом этаже. Квартиры на последнем этаже лишь немного дешевле квартир на других этажах.

# %% [markdown]
# ## Зависимость полной стоимости от даты размещения объявления
# Изучим зависимость полной стоимости объектов недвижимости от дня, месяца и года размещения объявления. Построим три диаграммы `bar plot` для столбцов `last_price` и `day`, `last_price` и `month`, `last_price` и `year` . Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[11,5])
df.groupby('day')['last_price'].mean().plot.bar()
plt.xlabel("День недели публикации объявления")
plt.ylabel("Средняя стоимость квартиры (млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от дня недели публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df.groupby('month')['last_price'].mean().plot.bar()
plt.xlabel("Месяц публикации объявления")
plt.ylabel("Средняя стоимость квартиры (млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от месяца публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df.groupby('year')['last_price'].mean().plot.bar()
plt.xlabel("Год публикации объявления")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от года публикации объявления")
plt.show()

# %%
[
    df['last_price'].corr(df['day']),
    df['last_price'].corr(df['month']),
    df['last_price'].corr(df['year'])
]
# Out:
# [-0.012690471179834384, 0.006188398396312344, -0.039447178990266875]

# %% [markdown]
# На основе полученных данных можно сказать, что дата публикации объявления не влияет на стоимость. Из общей картины выбивается только 2014 год, но это можно списать на малый объём данных, так как сервис Яндекс.Недвижимость запустился только в 2010 году.

# %% [markdown]
# ## Расчёт средней стоимости квадратного метра
# Выберем 10 населённых пунктов с наибольшим числом объявлений и посчитаем по ним среднюю цену квадратного метра.

# %%
df['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      15380
# посёлок Мурино         494
# посёлок Шушары         436
# Всеволожск             390
# Пушкин                 368
# Колпино                338
# посёлок Парголово      323
# Гатчина                306
# деревня Кудрово        283
# Выборг                 235
# Name: locality_name, dtype: int64

# %%
# Создадим список с ТОП-10 городов по количеству объявлений 
ls_of_cities = [
    'Санкт-Петербург',
    'посёлок Мурино',
    'посёлок Шушары',
    'Всеволожск',
    'Пушкин',
    'Колпино',
    'посёлок Парголово',
    'Гатчина',
    'деревня Кудрово',
    'Выборг'
]

# Создадим пустой список, куда будем класть среднюю цену квадратного метра
empty_ls = []
for i in ls_of_cities:
    value_mean = df.query('locality_name == @i')['price_square_meter'].mean()
    value_median = df.query('locality_name == @i')['price_square_meter'].median()
    empty_ls.append([i, value_mean, value_median])
    
# Выведем получившийся список
empty_ls
# Out:
# [['Санкт-Петербург', 111.17993498049404, 104.3],
#  ['посёлок Мурино', 85.07348178137647, 84.25],
#  ['посёлок Шушары', 78.40642201834858, 76.75],
#  ['Всеволожск', 67.2184615384615, 65.8],
#  ['Пушкин', 103.10190217391306, 100.0],
#  ['Колпино', 75.42426035502953, 74.7],
#  ['посёлок Парголово', 90.29009287925697, 91.9],
#  ['Гатчина', 68.75751633986928, 67.85],
#  ['деревня Кудрово', 92.2989399293286, 91.7],
#  ['Выборг', 58.23999999999997, 58.3]]

# %% [markdown]
# На основе полученных данных можно сказать, что из топ-10 городов самая низкая стоимость жилья в Выборге, а самая высокая в Санкт-Петербурге.

# %% [markdown]
# ## Определение центра города
# Выясним, какая область входит в центр. Так как в столбце `city_centers_nearest` есть пропуски, то создадим новый датафрейм `df_new`, где будут только квартиры в Санкт-Петербурге и без пропусков в столбце `city_centers_nearest`.

# %%
condition = (df['city_centers_nearest'].isnull() == False) & (df['locality_name']=='Санкт-Петербург')
df_new = (df.loc[condition]).copy()

# %% [markdown]
# Добавим в таблицу `df_new` столбец `to_center_in_kilometers`, в котором будет храниться расстояние до центра в километрах. Также приведём значения этого столбца из типа `float` к типу `int`.

# %%
df_new['to_center_in_kilometers'] = (df_new['city_centers_nearest']/1000).astype(int)

# %% [markdown]
# Построим сводную таблицу по `df_new`. Посчитаем среднюю и медианную стоимость за 1 м² для каждого километра.

# %%
df_new.pivot_table(index=['to_center_in_kilometers'], values=['price_square_meter'], aggfunc=['mean', 'median'])
# Out:
#                                       mean             median
#                         price_square_meter price_square_meter
# to_center_in_kilometers
# 0                               138.662857             127.90
# 1                               133.261818             118.85
# 2                               121.784859             111.90
# 3                               120.370276             109.65
# 4                               132.760502             125.00
# 5                               134.056346             123.00
# 6                               136.625576             129.10
# 7                               130.327461             123.50
# 8                               119.773676             113.80
# 9                               110.137135             105.30
# 10                              111.223925             105.60
# 11                              106.621795             103.10
# 12                              108.128533             103.70
# ...

# %% [markdown]
# Построим диаграмму рассеяния для столбцов `price_square_meter` и `to_center_in_kilometers`. Найдём коэффициент корреляции Пирсона.

# %%
df_new.plot(x='price_square_meter', y='to_center_in_kilometers', kind='scatter', alpha=0.1, figsize=[10,6])
plt.xlabel("Стоимость квадратного метра (тысяч рублей)")
plt.ylabel("Удалённость квартиры от центра города в километрах")
plt.title("Зависимость стоимости квадратного метра от удалённости от центра")
plt.show()

# %%
df_new['price_square_meter'].corr(df_new['to_center_in_kilometers'])
# Out:
# -0.3449617444213858

# %% [markdown]
# По сводной таблице видно, что стоимость за 1 м² сильно падает после 7 километра. На диаграмме рассеяния видно, что это происходит потому, что почти все квартиры стоимостью более 200 тысяч за 1 м² находятся в диапазоне от 0 до 7 километров. Таким образом центром города можно считать область радиусом в 7 километров.

# %% [markdown]
# ## Изучение параметров квартир для центра города
# Изучим такие параметры как площадь, цена, количество комнат и высота потолков для объектов недвижимости в центре города. Выделим сегмент квартир находящихся в радиусе 7 километров от центра города и помести их в таблицу `df_center`.

# %%
df_center = df_new.query('to_center_in_kilometers<=7')

# %% [markdown]
# ### Изучение общей площади для центра города
# Изучим площадь объектов недвижимости в центре города. Построим гистограммы и используем метод `describe()` для столбцов `total_area`, `ratio_living_to_total_area` и `ratio_kitchen_to_total_area`.

# %%
# Общая площадь
df_center['total_area'].describe()
# Out:
# count    3495.000000
# mean       84.855637
# std        42.941446
# min        12.000000
# 25%        55.000000
# 50%        75.500000
# 75%       102.500000
# max       374.600000
# Name: total_area, dtype: float64

# %%
# Отношение жилой площади к общей
df_center['ratio_living_to_total_area'].describe()
# Out:
# count    3495.000000
# mean        0.579894
# std         0.109546
# min         0.038462
# 25%         0.521398
# 50%         0.583333
# 75%         0.657400
# max         0.983447
# Name: ratio_living_to_total_area, dtype: float64

# %%
# Отношение площади кухни к общей
df_center['ratio_kitchen_to_total_area'].describe()
# Out:
# count    3495.000000
# mean        0.174267
# std         0.077869
# min         0.025381
# 25%         0.121853
# 50%         0.160000
# 75%         0.200000
# max         0.625000
# Name: ratio_kitchen_to_total_area, dtype: float64

# %%
plt.figure(figsize=[10,5])
df_center['total_area'].hist(bins=60)
plt.xlabel("Общая площадь квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по общей площади")
plt.show()

# %%
plt.figure(figsize=[10,5])
df_center['ratio_living_to_total_area'].hist(bins=30)
plt.xlabel("Доля жилой площади относительно общей площади квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по соотношению жилой площади к общей")
plt.show()

# %%
plt.figure(figsize=[10,5])
df_center['ratio_kitchen_to_total_area'].hist(bins=30)
plt.xlabel("Доля площади кухни относительно общей площади квартиры")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по соотношению площади кухни к общей")
plt.show()

# %% [markdown]
# Гистограммы площади для квартир в центре города идентичны гистограммам для квартир из общей выборки. Единственное отличие, что в центре больший процент квартир с площадью от 75 до 100 м².

# %% [markdown]
# ### Изучение стоимости квадратного метра для центра города
# Изучим стоимость 1 м² объектов недвижимости в центре города. Построим гистограмму и используем метод `describe()` для столбца `price_square_meter`.

# %%
df_center['price_square_meter'].describe()
# Out:
# count    3495.000000
# mean      130.694564
# std        46.629427
# min        15.300000
# 25%        99.300000
# 50%       121.000000
# 75%       149.500000
# max       392.400000
# Name: price_square_meter, dtype: float64

# %%
plt.figure(figsize=[10,5])
df_center['price_square_meter'].hist(bins=50)
plt.xlabel("Стоимость квадратного метра (тысяч рублей)")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по стоимости квадратного метра")
plt.show()

# %% [markdown]
# В отличии от гистограммы для квартир из общей выборки, гистограмма для квартир в центре города тяготеет к форме распределения Пуассона. Средняя стоимость за 1 м² квартир в центре выше на 30-35%.

# %% [markdown]
# ### Изучение количества комнат для центра города
# Изучим количество комнат для квартир в центре города. Построим гистограмму и используем метод `describe()` для столбца `rooms`.

# %%
df_center['rooms'].describe()
# Out:
# count    3495.000000
# mean        2.746209
# std         1.373755
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max        19.000000
# Name: rooms, dtype: float64

# %%
plt.figure(figsize=[10,5])
df_center['rooms'].hist(bins=5, range=(0, 10))
plt.xlabel("Количество комнат в квартире")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по количеству комнат")
plt.show()

# %% [markdown]
# В общей выборке среднестатистической квартирой считались двушки. Для центра города это уже трёшки.

# %% [markdown]
# ### Изучение высоты потолков для центра города
# Изучим высоту потолков для квартир в центре города. Построим гистограмму и используем метод `describe()` для столбца `ceiling_height`.

# %%
df_center['ceiling_height'].describe()
# Out:
# count    3495.000000
# mean        2.949402
# std         0.327996
# min         2.400000
# 25%         2.700000
# 50%         3.000000
# 75%         3.100000
# max         4.800000
# Name: ceiling_height, dtype: float64

# %%
plt.figure(figsize=[10,5])
df_center['ceiling_height'].hist(bins=20)
plt.xlabel("Высота потолка в квартире")
plt.ylabel("Количество квартир")
plt.title("Гистограмма распределения квартир по высоте потолка")
plt.show()

# %% [markdown]
# Почти во всех квартирах в центре города либо обычные нормальные потолки либо потолки от 3 метров.

# %% [markdown]
# ### Зависимость стоимости квадратного метра от количества комнат для центра города
# Изучим зависимость цены 1 м² от количества комнат для квартир в центре города. Построим диаграмму `bar plot` для столбцов `price_square_meter` и `rooms`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df_center.groupby('rooms')['price_square_meter'].mean().plot.bar()
plt.xlabel("Количество комнат квартиры")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от количества комнат")
plt.show()

# %%
df_center['price_square_meter'].corr(df['rooms'])
# Out:
# -0.22913859984423132

# %% [markdown]
# Прослеживается небольшая зависимость. Чем меньше комнат, тем дороже стоит квадратный метр.

# %% [markdown]
# ### Зависимость стоимости квадратного метра от этажа для центра города
# Изучим зависимость цены 1 м² от этажа для квартир в центре города. Построим диаграмму `bar plot` для столбцов `price_square_meter` и `flats_floor`.

# %%
plt.figure(figsize=[8,5])
df_center.groupby('flats_floor')['price_square_meter'].mean().plot.bar()
plt.xlabel("Этаж квартиры")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от этажа")
plt.show()

# %% [markdown]
# По диаграмме видно, что квадратный метр на первом или последнем этаже немного дешевле, чем на любом другом.

# %% [markdown]
# ### Зависимость стоимости квадратного метра от удалённости от центра для центра города
# Изучим зависимость цены 1 м² от удалённости от центра города для квартир в центре города. Построим диаграмму `bar plot` для столбцов `price_square_meter` и `to_center_in_kilometers`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df_center.groupby('to_center_in_kilometers')['price_square_meter'].mean().plot.bar()
plt.xlabel("Удалённость квартиры от центра города в километрах")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от удалённости от центра города")
plt.show()

# %%
df_center['price_square_meter'].corr(df_new['to_center_in_kilometers'])
# Out:
# 0.04780114774612777

# %% [markdown]
# На основе полученных данных можно сказать, что зависимости нет.

# %% [markdown]
# ### Зависимость стоимости квадратного метра от даты размещения объявления для центра города
# Изучим зависимость цены 1 м² от дня, месяца и года размещения объявления для квартир в центре города. Построим три диаграммы `bar plot` для столбцов `price_square_meter` и `day`, `price_square_meter` и `month`, `price_square_meter` и `year`. Найдём коэффициенты корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df_center.groupby('day')['price_square_meter'].mean().plot.bar()
plt.xlabel("День недели публикации объявления")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от дня недели публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df_center.groupby('month')['price_square_meter'].mean().plot.bar()
plt.xlabel("Месяц публикации объявления")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от месяца публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df_center.groupby('year')['price_square_meter'].mean().plot.bar()
plt.xlabel("Год публикации объявления")
plt.ylabel("Средняя стоимость 1 м² (тысяч рублей)")
plt.title("Зависимость стоимости 1 м² от года публикации объявления")
plt.show()

# %%
[
    df_center['price_square_meter'].corr(df['day']),
    df_center['price_square_meter'].corr(df['month']),
    df_center['price_square_meter'].corr(df['year'])
]
# Out:
# [0.014579417588193758, -0.029733296388648887, 0.07881052317955248]

# %% [markdown]
# Показатели абсолютно идентичны квартирам из общей выборки. Также выбивается 2014 год. Дата публикации объявления для центра города также не влияет на стоимость 1 м².

# %% [markdown]
# ### Зависимость полной стоимости от количества комнат для центра города
# Изучим зависимость полной стоимости от количества комнат для недвижимости в центре города. Построим `bar plot` для столбцов `last_price` и `rooms`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df_center.groupby('rooms')['last_price'].mean().plot.bar()
plt.xlabel("Количество комнат квартиры")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от количества комнат")
plt.show()

# %%
df_center['last_price'].corr(df_center['rooms'])
# Out:
# 0.4742427784733816

# %% [markdown]
# С ростом стоимости растёт количество комнат как для общей выборки, так и для центра города.

# %% [markdown]
# ### Зависимость полной стоимости от этажа для центра города
# Изучим зависимость полной стоимости от этажа для недвижимости в центре города. Построим `bar plot` для столбцов `last_price` и `flats_floor`.

# %%
plt.figure(figsize=[8,5])
df_center.groupby('flats_floor')['last_price'].mean().plot.bar()
plt.xlabel("Этаж квартиры")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от её этажа")
plt.show()

# %% [markdown]
# Первый этаж, также как и для квартир из общей выборки наименее привлекателен. Однако квартиры на последнем этаже сравнялись по стоимости с остальными, в отличии от общей выборки.

# %% [markdown]
# ### Зависимость полной стоимости от удалённости от центра для центра города
# Изучим зависимость полной стоимости от удалённости от центра города для недвижимости в центре города. Построим `bar plot` для столбцов `last_price` и `to_center_in_kilometers`. Найдём коэффициент корреляции Пирсона.

# %%
plt.figure(figsize=[10,5])
df_center.groupby('to_center_in_kilometers')['last_price'].mean().plot.bar()
plt.xlabel("Удалённость квартиры от центра города в километрах")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от удалённости от центра города")
plt.show()

# %%
df_center['last_price'].corr(df_center['to_center_in_kilometers'])
# Out:
# -0.07161198590485472

# %% [markdown]
# Квартиры дорожают по мере приближения к 0 километру, но незначительно.

# %% [markdown]
# ### Зависимость полной стоимости от даты размещения объявления для центра города
# Изучим зависимость полной стоимости от дня, месяца и года размещения объявления для недвижимости в центре города. Построим три диаграммы `bar plot` для столбцов `last_price` и `day`, `last_price` и `month`, `last_price` и `year`. Найдём коэффициенты корреляции Пирсона.

# %%
plt.figure(figsize=[11,5])
df_center.groupby('day')['last_price'].mean().plot.bar()
plt.xlabel("День недели публикации объявления")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от дня недели публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df_center.groupby('month')['last_price'].mean().plot.bar()
plt.xlabel("Месяц публикации объявления")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от месяца публикации объявления")
plt.show()

# %%
plt.figure(figsize=[10,5])
df_center.groupby('year')['last_price'].mean().plot.bar()
plt.xlabel("Год публикации объявления")
plt.ylabel("Средняя стоимость квартиры (* 10 млн. рублей)")
plt.title("Зависимость полной стоимости квартиры от года публикации объявления")
plt.show()

# %%
[
    df_center['last_price'].corr(df_center['day']),
    df_center['last_price'].corr(df_center['month']),
    df_center['last_price'].corr(df_center['year'])
]
# Out:
# [0.000528675607550328, -0.022354366439056448, -0.012762030305442339]

# %% [markdown]
# На основе полученных данных можно сказать, что дата публикации объявления не влияет на стоимость. Из общей картины выбивается только 2014 год, но это можно списать на малый объём данных, так как сервис Яндекс.Недвижимость запустился только в 2010 году.

# %% [markdown]
# # Общий вывод
#
# + Подавляющее большинство квартир имеют площадь от 25 до 100 м².
# + Кухня обычно занимает от 10% до 20% общей площади.
# + Жилая площадь обычно занимает от 40% до 70% общей площади.
# + Стоимость в среднем колеблется от 50 до 140 тысяч за квадратный метр, а если это центр города, то от 75 до 160 тысяч за квадратный метр.
# + Высокие потолки - это потолки от 3 метров и они более свойственны квартирам в центре города.
# + Центр города - это область радиусом в 7 километров.
# + Продать квартиру быстро - это продать её менее, чем за 3 месяца.
# + Если вы продаёте квартиру на 1 этаже, будьте готовы к ожиданию дольше обычного.
# + Квартиры продаются одинаково в любое время года.
